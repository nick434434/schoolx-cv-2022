# %% [markdown]
# # Введение в Python - задачи для самостоятельного решения

# %% [markdown]
# ## Работа с библиотеками

# %% [markdown]
# Чтобы найти название пока ещё неизвестной вам библиотеки, нужно поискать её в реестре [PyPi](https://pypi.org)
#
# Попробуем установить первую библиотеку, заодно посмотрев, как утилита установки сама разрешает зависимости, если они не указаны явно. В jupyter notebook консольные команды можно выполнять в обычных блоках кода - необходимо только добавить символ ! в начало строки

# %%
# Установите библиотеку OpenCV, прописав нужную команду перед названием пакета. Она зависит от пакета NumPy, но его мы явно указывать не будем
# (в Google Colab они уже будут установлены, в случае верного исполнения ожидается сообщение 'Requirement already satisfied')
! opencv-python

# %% [markdown]
# ## Структура файла, общепринятый синтаксис

# %%
# Отредактируйте кусок кода ниже, чтобы он соответствовал принятому стилю и конвенциям PEP о хорошем коде
# Постарайтесь не запускать ячейку для проверки корректности
import cv2

import time.time
def main() :
  print (cv2. __version__,time());
return 0;



main()

# %% [markdown]
# ## Циклы, условия, стандартная библиотека

# %% [markdown]
# Задача 1: дан массив целых чисел, для которого нужно узнать, какое положительное число является первым отсутствующим в ряду натуральных чисел. Предполагается, что массив гарантированно удовлетворяет условию единственности такого числа (не более одной "дырки" в натуральной части), а также НЕ является отсортированным
#
# Например: [1, 2, 4, 5, 6] -> 3; [-2, 2, 3, 4] -> 1, [1, 2, 3] -> 4.
#
# Реализуйте функцию для решения данной задачи, используя множество, цикл, условия и range. Будет круто, если получится вместо циклов использовать comprehensions. Оцените временную сложность получившегося алгоритма, используя обозначения Big O, и запишите её в комментарий сразу после шапки функции.

# %%
def solution1():
    pass

# %%
assert solution1([4, 6, 1, 5, 2]) == 3
assert solution1([3, 2, -2, 4]) == 1
assert solution1(list(set(range(1000)) - {4})) == 4

# %% [markdown]
# Задача 2: даны два кортежа с цифрами, представляющие собой два числа (то есть, вход - кортеж из двух кортежей. Для наглядности можно распечатать tests[0][0] (входной аргумент первого теста)). Реализовать функцию, которая будет осуществлять сложение в столбик этих двух чисел и выдавать ответ также в виде кортежа. Попробуйте оценить сложность по времени и по памяти без Big O, то есть с использованием умножающих констант (например, алгоритм, в котором есть два цикла п исходному массиву, невложенные друг в друга, будет занимать 2n)

# %%
def solution2():
    pass

# %%
tests = [
    (((1, 2, 3, 4, 5), (6, 7)), (1, 2, 4, 1, 2)),
    (((9, 8, 7), (9, 9, 9)), (1, 9, 8, 6)),
    (((), (1, 2, 3)), (1, 2, 3))
]

for inp, ans in tests:
    assert solution2(inp) == ans
